# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?
# Ans:
# 1st we have to install bokeh using pip.
# 2nd we import bokeh.io,
# Then we import bokeh.plotting
# then we import bokeh.io.output_notebook().
# Then we will import figure , output_file , show from bokeh.plotting.
# Then we wll do the plotting according to our requirement.

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.
# Ans:
# Glyphs are the building blocks of Bokeh visualizations. A glyph is a vectorized graphical shape or marker that is used to represent the data. There are a few different categories of glyphs.They can be a marker—shapes like circles, diamonds, squares, and triangles.
#    To draw a line glyph to a figure, we use the line() method of the figure object.In order to add the circle glyph to our plot, we use the circle() method . Similarly, we can render bars using vbar() function for vertical bars and hbar() function for horizontal bars and so on.
#  #We use the circle glyph in this case as example
# from bokeh.plotting import figure,output_file , show
# from bokeh.sampledata.iris import flowers
#
# output_file('test.html')
#
# p = figure(title = 'test_flower')
# p.xaxis.axis_label = 'petal length'
# p.yaxis.axis_label = 'petal width'
# p.circle(flowers['petal_length'] , flowers['petal_width'])
# show(p)
#
# Output= ['']

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?
#
# Ans: We can understand better with an example.Lets take iris dataset from seaborn for the example.
#
# from bokeh.plotting import figure,output_file , show
# from bokeh.sampledata.iris import flowers
#
# output_file('test.html')
#
# p = figure(title = 'test_flower')
# p.xaxis.axis_label = 'petal length'
# p.yaxis.axis_label = 'petal width'
# p.circle(flowers['petal_length'] , flowers['petal_width'])
# show(p)
#
# Here we can customize the appearance by changing the 2nd last line. Here we plotted the data using circle plot. If we want to plot line type then we will change the code to
# p.line(flowers['petal_length'] , flowers['petal_width'])
# We can the axis by changing "p.xaxis.axis_label = 'petal length'
# p.yaxis.axis_label = 'petal width'" these 2 lines , title by modifying the name on "p = figure(title = 'test_flower')" this code. and if we want to add legend then we just need to add legend_label on the 2nd last line of the code.

# %% [markdown]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in real time?
# Ans:
# Bokeh is a library of Python which is used to create interactive data visualizations.The Bokeh server is a component of Bokeh that allows to build interactive web applications that are connected to Python code running on a server.
# Building a visualization with Bokeh involves the following steps:
# 1.Prepare the data.
# 2.Determine where the visualization will be rendered.
# 3.Set up the figure(s).
# 4.Connect to and draw your data.
# 5.Organize the layout.
# 6.Preview and save your beautiful data creation.
# 7. start_date and end_date define the range of dates.
# 8.This application uses Select, DatePicker, and Spinner widgets. fund_2 is a Select widget which creates a drop-down menu of indexes. start_date_picker and end_date_picker use the DatePicker widget which includes a pop-up calendar to easily pick the date range.

# %% [markdown]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?
# Ans:
# To embed a bokeh plot into a web page or dashboard using Django or flask ,we will be importing components from bokeh.embed which returns the individual components. The function bokeh.embed.components() returns a script that contains that data for your plot with a <div> tag in which the plot view is loaded.
# 1st step is to setting up a basic Django project
#     2nd step to create a Django project
#     And step 3 is to complete the bokeh setup into the project.
#     For this step  let’s create a template folder in our BokehApp directory and save it as templates. Create a new file in the templates directory and save it as base.html. Add "<link href=”http://cdn.pydata.org/bokeh/release/bokeh-2.3.2.min.css
#    " rel=”stylesheet” type=”text/css”>
# <link href=”http://cdn.pydata.org/bokeh/release/bokeh-widgets-2.3.2.min.css"
#    rel=”stylesheet” type=”text/css”>" links of CSS in our base.html file in the head tag and replace the version of your bokeh at the place bokeh-x.y.z.min (underlined place  x.y.z) and the javascript links"<script src="https://cdn.bokeh.org/bokeh/release/bokeh-2.3.2.min.js"></script>
# <script src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.3.2.min.js"></script>
# <script src="https://cdn.bokeh.org/bokeh/release/bokeh-tables-2.3.2.min.js"></script>
# <script src="https://cdn.bokeh.org/bokeh/release/bokeh-api-2.3.2.min.js"></script>" after </body> and similarly replace our bokeh version at x.y.z.
# The bas html will look like this.
# <html>
#    <head>
#       <link href=”http://cdn.pydata.org/bokeh/release/bokeh-2.3.2.min.css
#          " rel=”stylesheet” type=”text/css”>
#       <link href=”http://cdn.pydata.org/bokeh/release/bokeh-widgets-2.3.2.min.css"
#          rel=”stylesheet” type=”text/css”>
#    </head>
#    <body>
#       <h1>Our first Bokeh Graph</h1>
#       {{div| safe}}
#    </body>
#    <script src="https://cdn.bokeh.org/bokeh/release/bokeh-2.3.2.min.js"></script>
#    <script src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.3.2.min.js"></script>
#    <script src="https://cdn.bokeh.org/bokeh/release/bokeh-tables-2.3.2.min.js"></script>
#    <script src="https://cdn.bokeh.org/bokeh/release/bokeh-api-2.3.2.min.js"></script>
#    {{script| safe}}
# </html>
# Then replace the view function home so that it renders our first graph. Add the below code which creates basic circle scatter marks on our plot:
#
# from django.shortcuts import render
# from django.http import HttpResponse
# from bokeh.plotting import figure
# from bokeh.embed import components
#
# # Create your views here.
#
# def home(request):
#
#    #create a plot
#     plot = figure(plot_width=400, plot_height=400)
#
#    # add a circle renderer with a size, color, and alpha
#
#    plot.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)
#
#    script, div = components(plot)
#
#    return render(request, 'base.html', {'script': script, 'div': div})
#
# The components method returns a script that contains the data for our plot and provides a <div>tag to display the plot view. These two elements can be inserted into the HTML text and the <script> when executed will replace the div with the plot.
# The circle method is a glyph method which is a method of the figure object. Glyphs are the basic visual building blocks of Bokeh plots. This includes elements such as lines, rectangles, squares, wedges, or the circles of a scatter plot
# The plot variable enables us to create a plot that holds all the various objects such as glyphs, annotations, etc. of a visualization.
